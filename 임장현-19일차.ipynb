# %% [markdown]
# #### 18일차 복습

# %% [markdown]
# import csv
#
# f = open('파일디렉토리', 'r', 'endcoding = utf-8, cp949')
# data = csv.reader(f)
#
# for row in data:
#
#
# csv(comma seperated value)

# %% [markdown]
# #### matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### numpy

# %% [markdown]
# numpy는 array로 기본 구성이 되어있다.
# - ndarray
#
# pandas는 numpy를 바탕으로 만들어졌다.
# - pandas에서 열은 series라고 불림.
# - 테이블을 dataframe이라고 불림.

# %% [markdown]
# ### 04. CSV 파일로 데이터 다루기
# #### 04-01. csv 데이터 알아보기
# #### 04-02. csv 파일 읽고 쓰기
# - use.csv
# - 기본형으로 리스트를 사용한다.(중첩리스트) : csv형 list

# %%
import os
os.chdir(r'c:\doit\life')

# %%
import csv

# %%
f = open(r'c:\doit\life\a.csv', 'r')
new = csv.reader(f)

for i in new:
    print(i)
# Out:
# ['국어', '영어', '수학']
# ['90', '80', '100']

# %%
f.seek(0) # 커서를 처음으로 이동합니다.
          # 0이 출력되면 커서가 처음으로 이동했다는 의미입니다.
a_list = []
for i in new:
    print(i)
    a_list.append(i)

a_list
# Out:
# ['국어', '영어', '수학']
# ['90', '80', '100']
# [['국어', '영어', '수학'], ['90', '80', '100']]

# %%
def opencsv(filename):
    f = open(filename, 'r')
    reader = csv.reader(f)
    output = []
    for i in reader:
        output.append(i)
    return output

# %%
opencsv('example2.csv')
# Out:
# [['이름', '국어', '영어', '수학'],
#  ['a', '90', '80', '100'],
#  ['b', '80', '90', '90'],
#  ['c', '100', '80', '60']]

# %%
a = [['구','전체','내국인','외국인'],
['관악구','519864','502089','17775'],
['강남구','547602','542498','5104'],
['송파구','686181','679247','6934'],
['강동구','428247','424235','4312']]

# %%
f = open('abc.csv', 'w', newline = '')
csvobject = csv.writer(f, delimiter = ',') #delimiter = 구분자
csvobject.writerows(a)
f.close()

# %%
def writecsv(filename, the_list):
    with open(filename, 'w', newline = '') as f:
        a = csv.writer(f, delimiter = ',')
        a.writerows(the_list)

# %%
writecsv('abc.scv', a)

# %%
import usecsv
os.chdir(r'c:\doit\life')
a = [['물리', '화학', '생물'], [70, 99, 100]]
usecsv.writecsv('test.csv', a)

# %% [markdown]
# #### 04-03. csv 파일 안의 문자를 숫자로 전환하기

# %%
import os, re
import usecsv
os.chdir(r'c:\doit\life')
total = usecsv.opencsv('popSeoul.csv')

# %%
total
# Out:
# [['Gu', 'Korean', 'Foreigner', 'Senior'],
#  ['Total', '9,740,398', '285,529', '1,468,146'],
#  ['Jongrogu', '151,767', '11,093', '27,394'],
#  ['Jongru', '126,409', '10,254', '23,025'],
#  ['Yongsangu', '228,830', '16,159', '38,531'],
#  ['Seongdonggu', '303,158', '8,132', '43,662'],
#  ['Kwangjingu', '352,692', '15,645', '47,347'],
#  ['Dongdaemoongu', '346,551', '17,228', '58,764'],
#  ['Jungranggu', '398,812', '4,964', '64,449'],
#  ['Seongbukgu', '441,590', '12,524', '70,204'],
#  ['Gangbukgu', '314,090', '3,785', '59,808'],
#  ['Dobonggu', '335,280', '2,314', '58,070'],
#  ['Nowonggu', '535,282', '4,547', '79,968'],
#  ['Eunpyonggu', '481,663', '4,496', '79,957'],
#  ['Seodaemungu', '310,069', '14,020', '51,708'],
#  ['Mapogu', '373,629', '11,976', '51,961'],
#  ['Yangcheongu', '459,849', '4,082', '60,487'],
#  ['Gangseogu', '593,708', '6,532', '82,937'],
#  ['Gurogu', '406,748', '33,102', '64,952'],
#  ['Guemcheongu', '233,371', '19,497', '37,191'],
# ...

# %%
for i in total[:5]:
    print(i)
# Out:
# ['Gu', 'Korean', 'Foreigner', 'Senior']
# ['Total', '9,740,398', '285,529', '1,468,146']
# ['Jongrogu', '151,767', '11,093', '27,394']
# ['Jongru', '126,409', '10,254', '23,025']
# ['Yongsangu', '228,830', '16,159', '38,531']

# %%
import re
i = total[2]
i

k = []

for j in i:
    if re.search('\d', j):
        k.append(float(re.sub(',', '', j)))
    else:
        k.append(j)
k
# Out:
# ['Jongrogu', 151767.0, 11093.0, 27394.0]

# %%
p = ['123강남', '151,767', '11,093', '27,394']
k = []

for j in p:
    if re.search('[a-z가-힣]', j):
        k.append(j)
    else:
        k.append(j)
k
# Out:
# ['123강남', '151,767', '11,093', '27,394']

# %%
p = ['123강남!', '151,767', '11,093', '27,394']
k = []

for j in p:
    if re.search('[a-z가-힣!]', j):
        k.append(j)
    else:
        k.append(float(re.sub(',','',j)))
k
# Out:
# ['123강남!', 151767.0, 11093.0, 27394.0]

# %%
i = ['123!!', '151,767', '11,093', '27,394']
for j in i:
    if re.search('[a-z가-힣!]', j):
        k.append(j)
    else:
        k.append(float(re.sub(',', '', j)))
        
k
# Out:
# ['123강남!', 151767.0, 11093.0, 27394.0, '123!!', 151767.0, 11093.0, 27394.0]

# %%
i = ['123!!', '151,767', '11,093', '27,394', '', '!!!$%']

for j in i:
    try:
        i[i.index(j)] = float(re.sub(',', '', j))
    except:
        pass
    
i
# Out:
# ['123!!', 151767.0, 11093.0, 27394.0, '', '!!!$%']

# %%
total

i = total[1]
for j in i:
    try:
        i[i.index(j)] = float(re.sub(',', '', j))
    except:
        pass

i

for i in total:
    for j in i:
        try:
            i[i.index(j)] = float(re.sub(',', '', j))
        except:
            pass
total
# Out:
# [['Gu', 'Korean', 'Foreigner', 'Senior'],
#  ['Total', 9740398.0, 285529.0, 1468146.0],
#  ['Jongrogu', 151767.0, 11093.0, 27394.0],
#  ['Jongru', 126409.0, 10254.0, 23025.0],
#  ['Yongsangu', 228830.0, 16159.0, 38531.0],
#  ['Seongdonggu', 303158.0, 8132.0, 43662.0],
#  ['Kwangjingu', 352692.0, 15645.0, 47347.0],
#  ['Dongdaemoongu', 346551.0, 17228.0, 58764.0],
#  ['Jungranggu', 398812.0, 4964.0, 64449.0],
#  ['Seongbukgu', 441590.0, 12524.0, 70204.0],
#  ['Gangbukgu', 314090.0, 3785.0, 59808.0],
#  ['Dobonggu', 335280.0, 2314.0, 58070.0],
#  ['Nowonggu', 535282.0, 4547.0, 79968.0],
#  ['Eunpyonggu', 481663.0, 4496.0, 79957.0],
#  ['Seodaemungu', 310069.0, 14020.0, 51708.0],
#  ['Mapogu', 373629.0, 11976.0, 51961.0],
#  ['Yangcheongu', 459849.0, 4082.0, 60487.0],
#  ['Gangseogu', 593708.0, 6532.0, 82937.0],
#  ['Gurogu', 406748.0, 33102.0, 64952.0],
#  ['Guemcheongu', 233371.0, 19497.0, 37191.0],
#  ['Youngdeungpogu', 368402.0, 34076.0, 57350.0],
# ...

# %%
import re
def switch(listName):
    for i in listName:
        for j in i:
            try:
                i[i.index(j)] = float(re.sub(',', '', j))
            except:
                pass
            
    return listName

# %%
row = [1, 2, 3, 4, 5]
row[row.index(5)]
# Out:
# 5

# %%
import usecsv

# %%
i = [['123강남!!', '151,767', '11,093', '27,394', '', '!!!$%']]

usecsv.switch(i)
# Out:
# [['123강남!!', 151767.0, 11093.0, 27394.0, '', '!!!$%']]

# %% [markdown]
# #### 04-04. csv 파일 데이터 분석하기

# %% [markdown]
# - 1. CSV형 리스트로 바꾸기

# %%
import os, re, usecsv
os.chdir(r'c:\doit\life')
total = usecsv.opencsv('popSeoul.csv')
newPop = usecsv.switch(total)
print(newPop[:4])
# Out:
# [['Gu', 'Korean', 'Foreigner', 'Senior'], ['Total', 9740398.0, 285529.0, 1468146.0], ['Jongrogu', 151767.0, 11093.0, 27394.0], ['Jongru', 126409.0, 10254.0, 23025.0]]

# %% [markdown]
# - 2. 등록외국인 비율 계산하기

# %%
i = newPop[1]
i
# Out:
# ['Total', 9740398.0, 285529.0, 1468146.0]

# %%
i[2] / (i[1] + i[2]) * 100
# Out:
# 2.847906233508383

# %%
foreign = round(i[2] / (i[1] + i[2]) * 100, 1)
foreign
# Out:
# 2.8

# %%
newPop
# Out:
# [['Gu', 'Korean', 'Foreigner', 'Senior'],
#  ['Total', 9740398.0, 285529.0, 1468146.0],
#  ['Jongrogu', 151767.0, 11093.0, 27394.0],
#  ['Jongru', 126409.0, 10254.0, 23025.0],
#  ['Yongsangu', 228830.0, 16159.0, 38531.0],
#  ['Seongdonggu', 303158.0, 8132.0, 43662.0],
#  ['Kwangjingu', 352692.0, 15645.0, 47347.0],
#  ['Dongdaemoongu', 346551.0, 17228.0, 58764.0],
#  ['Jungranggu', 398812.0, 4964.0, 64449.0],
#  ['Seongbukgu', 441590.0, 12524.0, 70204.0],
#  ['Gangbukgu', 314090.0, 3785.0, 59808.0],
#  ['Dobonggu', 335280.0, 2314.0, 58070.0],
#  ['Nowonggu', 535282.0, 4547.0, 79968.0],
#  ['Eunpyonggu', 481663.0, 4496.0, 79957.0],
#  ['Seodaemungu', 310069.0, 14020.0, 51708.0],
#  ['Mapogu', 373629.0, 11976.0, 51961.0],
#  ['Yangcheongu', 459849.0, 4082.0, 60487.0],
#  ['Gangseogu', 593708.0, 6532.0, 82937.0],
#  ['Gurogu', 406748.0, 33102.0, 64952.0],
#  ['Guemcheongu', 233371.0, 19497.0, 37191.0],
#  ['Youngdeungpogu', 368402.0, 34076.0, 57350.0],
# ...

# %% [markdown]
# - 3. 각 구의 외국인 비율 출력하기

# %%
for i in newPop:
    foreign = 0
    try:
        foreign = round(i[2] / (i[1] + i[2]) * 100, 1)
        print(i[0], foreign)
    except:
        pass
# Out:
# Total 2.8
# Jongrogu 6.8
# Jongru 7.5
# Yongsangu 6.6
# Seongdonggu 2.6
# Kwangjingu 4.2
# Dongdaemoongu 4.7
# Jungranggu 1.2
# Seongbukgu 2.8
# Gangbukgu 1.2
# Dobonggu 0.7
# Nowonggu 0.8
# Eunpyonggu 0.9
# Seodaemungu 4.3
# Mapogu 3.1
# Yangcheongu 0.9
# Gangseogu 1.1
# Gurogu 7.5
# Guemcheongu 7.7
# Youngdeungpogu 8.5
# Dongjakgu 3.1
# Kwanakgu 3.4
# Seoucheogu 1.0
# Gangnamgu 0.9
# Songpagu 1.0
# Gangdonggu 1.0

# %% [markdown]
# - 4. 첫 행 지정하기

# %%
new = [['구', '한국인', '외국인', '외국인 비율(%)']]
i
# Out:
# ['Gangdonggu', 426219.0, 4303.0, 61710.0]

# %%
new.append([i[0], i[1], i[2], foreign])
new
# Out:
# [['구', '한국인', '외국인', '외국인 비율(%)'], ['Gangdonggu', 426219.0, 4303.0, 1.0]]

# %% [markdown]
# - 5. 외국인 비율이 3% 초과할 때만 출력해보기

# %%
import re

for i in newPop:
    foreign = 0
    try:
        foreign = round(i[2] / (i[1] + i[2]) * 100, 1)
        if foreign > 3:
            print([i[0], i[1], i[2], foreign])
    except:
        pass
# Out:
# ['Jongrogu', 151767.0, 11093.0, 6.8]
# ['Jongru', 126409.0, 10254.0, 7.5]
# ['Yongsangu', 228830.0, 16159.0, 6.6]
# ['Kwangjingu', 352692.0, 15645.0, 4.2]
# ['Dongdaemoongu', 346551.0, 17228.0, 4.7]
# ['Seodaemungu', 310069.0, 14020.0, 4.3]
# ['Mapogu', 373629.0, 11976.0, 3.1]
# ['Gurogu', 406748.0, 33102.0, 7.5]
# ['Guemcheongu', 233371.0, 19497.0, 7.7]
# ['Youngdeungpogu', 368402.0, 34076.0, 8.5]
# ['Dongjakgu', 397618.0, 12869.0, 3.1]
# ['Kwanakgu', 502117.0, 17836.0, 3.4]

# %%
#김재경 교수님 방법
newList = []
newList.append(newPop[0])

for i in newPop:
    foreign = 0
    try:
        foreign = round(i[2] / (i[1] + i[2]) * 100, 1)
        print(i[0], foreign)
    except Exception as e:
        print(e)
    if foreign > 3:
        newList.append(i)

usecsv.writecsv('foreignover3.csv', newList)
# Out:
# unsupported operand type(s) for /: 'str' and 'str'
# Total 2.8
# Jongrogu 6.8
# Jongru 7.5
# Yongsangu 6.6
# Seongdonggu 2.6
# Kwangjingu 4.2
# Dongdaemoongu 4.7
# Jungranggu 1.2
# Seongbukgu 2.8
# Gangbukgu 1.2
# Dobonggu 0.7
# Nowonggu 0.8
# Eunpyonggu 0.9
# Seodaemungu 4.3
# Mapogu 3.1
# Yangcheongu 0.9
# Gangseogu 1.1
# Gurogu 7.5
# Guemcheongu 7.7
# Youngdeungpogu 8.5
# Dongjakgu 3.1
# Kwanakgu 3.4
# Seoucheogu 1.0
# Gangnamgu 0.9
# Songpagu 1.0
# Gangdonggu 1.0

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.DataFrame(newList[1:], columns = newList[0])
df
# Out:
#                 Gu    Korean  Foreigner   Senior
# 0         Jongrogu  151767.0    11093.0  27394.0
# 1           Jongru  126409.0    10254.0  23025.0
# 2        Yongsangu  228830.0    16159.0  38531.0
# 3       Kwangjingu  352692.0    15645.0  47347.0
# 4    Dongdaemoongu  346551.0    17228.0  58764.0
# 5      Seodaemungu  310069.0    14020.0  51708.0
# 6           Mapogu  373629.0    11976.0  51961.0
# 7           Gurogu  406748.0    33102.0  64952.0
# 8      Guemcheongu  233371.0    19497.0  37191.0
# 9   Youngdeungpogu  368402.0    34076.0  57350.0
# 10       Dongjakgu  397618.0    12869.0  61607.0
# 11        Kwanakgu  502117.0    17836.0  74518.0

# %%
plt.figure(figsize = (15, 10), dpi = 200)
plt.rc('font', family = 'Malgun Gothic')
plt.plot(df['Gu'], df['Korean'], label = '한국인')
plt.plot(df['Gu'], df['Foreigner'], label = '외국인')
plt.plot(df['Gu'], df['Senior'], label = '노인')
plt.title('서울시 인구 분포 현황')
plt.legend()
plt.show()

# %% [markdown]
# #### 부동산 실거래가 살펴보기
# - 1. CSV 파일 준비하기
# - 2. CSV형 리스트로 만들고 자료 가공하기

# %%
import usecsv

apt = usecsv.opencsv('apt.csv')
apt = usecsv.switch(apt)
apt
# Out:
# [['시군구',
#   '번지',
#   '본번',
#   '부번',
#   '단지명',
#   '전용면적(㎡)',
#   '계약년월',
#   '계약일',
#   '거래금액(만원)',
#   '층',
#   '건축년도',
#   '도로명',
#   '해제사유발생일',
#   '거래유형',
#   '중개사소재지'],
#  ['강원도 강릉시 견소동',
#   202.0,
#   202.0,
#   0.0,
#   '송정한신',
#   59.8,
#   202203.0,
#   7.0,
#   18000.0,
#   3.0,
#   1997.0,
#   '경강로2539번길 8',
#   '',
#   '중개거래',
#   '강원 강릉시'],
#  ['강원도 강릉시 견소동',
#   202.0,
#   202.0,
#   0.0,
#   '송정한신',
#   59.8,
#   202203.0,
#   8.0,
#   21000.0,
#   8.0,
#   1997.0,
#   '경강로2539번길 8',
#   '',
#   '중개거래',
#   '강원 강릉시'],
#  ['강원도 강릉시 견소동',
#   202.0,
#   202.0,
#   0.0,
#   '송정한신',
#   84.945,
#   202203.0,
#   26.0,
#   25500.0,
#   10.0,
#   1997.0,
#   '경강로2539번길 8',
#   '',
#   '중개거래',
#   '강원 강릉시'],
#  ['강원도 강릉시 견소동',
#   289.0,
#   289.0,
#   0.0,
#   '송정해변신도브래뉴아파트',
#   84.99,
#   202203.0,
#   14.0,
#   33500.0,
#   1.0,
#   2005.0,
#   '경강로2539번길 22',
#   '',
#   '중개거래',
#   '강원 강릉시'],
#  ['강원도 강릉시 견소동',
#   289.0,
#   289.0,
#   0.0,
#   '송정해변신도브래뉴아파트',
# ...

# %%
apt[:3]
# Out:
# [['시군구',
#   '번지',
#   '본번',
#   '부번',
#   '단지명',
#   '전용면적(㎡)',
#   '계약년월',
#   '계약일',
#   '거래금액(만원)',
#   '층',
#   '건축년도',
#   '도로명',
#   '해제사유발생일',
#   '거래유형',
#   '중개사소재지'],
#  ['강원도 강릉시 견소동',
#   202.0,
#   202.0,
#   0.0,
#   '송정한신',
#   59.8,
#   202203.0,
#   7.0,
#   18000.0,
#   3.0,
#   1997.0,
#   '경강로2539번길 8',
#   '',
#   '중개거래',
#   '강원 강릉시'],
#  ['강원도 강릉시 견소동',
#   202.0,
#   202.0,
#   0.0,
#   '송정한신',
#   59.8,
#   202203.0,
#   8.0,
#   21000.0,
#   8.0,
#   1997.0,
#   '경강로2539번길 8',
#   '',
#   '중개거래',
#   '강원 강릉시']]

# %%
len(apt)
# Out:
# 23900

# %% [markdown]
# - 3. 슬라이싱으로 원하는 자료 출력하기

# %%
apt[0]
# Out:
# ['시군구',
#  '번지',
#  '본번',
#  '부번',
#  '단지명',
#  '전용면적(㎡)',
#  '계약년월',
#  '계약일',
#  '거래금액(만원)',
#  '층',
#  '건축년도',
#  '도로명',
#  '해제사유발생일',
#  '거래유형',
#  '중개사소재지']

# %%
for i in apt[:6]: # 처음 6개 원소에 대해서 반복
    print(i[0])
# Out:
# 시군구
# 강원도 강릉시 견소동
# 강원도 강릉시 견소동
# 강원도 강릉시 견소동
# 강원도 강릉시 견소동
# 강원도 강릉시 견소동

# %%
for i in apt[:6]:
    print(i[0], i[4], i[5], i[-7])
# Out:
# 시군구 단지명 전용면적(㎡) 거래금액(만원)
# 강원도 강릉시 견소동 송정한신 59.8 18000.0
# 강원도 강릉시 견소동 송정한신 59.8 21000.0
# 강원도 강릉시 견소동 송정한신 84.945 25500.0
# 강원도 강릉시 견소동 송정해변신도브래뉴아파트 84.99 33500.0
# 강원도 강릉시 견소동 송정해변신도브래뉴아파트 59.99 27000.0

# %% [markdown]
# - 4. 강원도에 120제곱미터 이상 3억 원 이하 아파트 검색하기

# %%
for i in apt:
    try:
        if i[5] >= 80 and i[-7] <= 30000 and re.match('대전', i[0]):
            print(i[0], i[4], i[5], i[-7])
    except: pass
# Out:
# 대전광역시 대덕구 법동 영진로얄 84.88 26700.0
# 대전광역시 대덕구 비래동 화인빌 81.389 13000.0
# 대전광역시 대덕구 신탄진동 새여울라이프 101.67 20000.0
# 대전광역시 대덕구 오정동 영진로얄맨션 84.28 16900.0
# 대전광역시 대덕구 오정동 한남 84.97 18800.0
# 대전광역시 대덕구 읍내동 현대 84.96 24500.0
# 대전광역시 동구 가양동 한울 84.8698 27000.0
# 대전광역시 동구 대성동 서미가아파트 84.959 20000.0
# 대전광역시 동구 판암동 방주아파트 84.93 26000.0
# 대전광역시 서구 가수원동 은아1단지 84.9 29500.0
# 대전광역시 서구 갈마동 갈마 84.68 27500.0
# 대전광역시 서구 갈마동 한국도로공사조합아파트 84.9 20088.0
# 대전광역시 서구 내동 롯데 84.99 29800.0
# 대전광역시 서구 월평동 월평타운 84.895 25000.0
# 대전광역시 서구 정림동 강변들금성백조 84.81 27000.0
# 대전광역시 서구 정림동 우성 84.935 30000.0
# 대전광역시 유성구 대정동 드리움1단지 84.65 30000.0
# 대전광역시 유성구 봉명동 노블레스3 84.61 24000.0
# 대전광역시 유성구 송강동 송강그린 84.996 30000.0
# 대전광역시 유성구 송강동 청솔신호 84.44 25300.0
# 대전광역시 유성구 송강동 청솔태영 84.44 24700.0
# 대전광역시 유성구 지족동 가나파로스빌2차 84.14 27500.0
# 대전광역시 중구 문화동 동양맨션마동 84.9 17000.0
# 대전광역시 중구 오류동 쉐리움 83.27 21000.0
# 대전광역시 중구 유천동 당대마을 82.169 17500.0
# 대전광역시 중구 유천동 동양맨션 84.97 17700.0

# %%
import re
new_list = []
new_list.append([apt[0][0], apt[0][4], apt[0][5], apt[0][-7]])

for i in apt:
    try:
        if i[5] >= 80 and i[-7] <= 30000 and re.match('대전', i[0]):
            new_list.append([i[0], i[4], i[5], i[-7]])
    except Exception as e:
        print(e)

usecsv.writecsv('대전지역 싼 아파트.csv', new_list)
# Out:
# '>=' not supported between instances of 'str' and 'int'
