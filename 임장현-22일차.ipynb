# %% [markdown]
# ### 웹 크롤링으로 정보 모으기

# %%
import os, re, usecsv
os.chdir('C:\doit\life')

# %%
# !pip install beautifulsoup4

# %%
import requests
import urllib.request as ur
from bs4 import BeautifulSoup as bs

# %%
url = 'http://quotes.toscrape.com'

# %%
html = ur.urlopen(url)
html

# %%
html.read()[:100]
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n   '

# %%
type(html)
# Out:
# http.client.HTTPResponse

# %%
html = ur.urlopen(url)
soup = bs(html.read(), 'html.parser')
soup = bs(ur.urlopen(url).read(), 'html.parser')
quote = soup.find_all('span')
quote[0].text
# Out:
# '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”'

# %%
for i in quote:
    print(i.text)
# Out:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# by Albert Einstein
# (about)
#
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# by J.K. Rowling
# (about)
#
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# by Albert Einstein
# (about)
#
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# by Jane Austen
# (about)
#
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# by Marilyn Monroe
# (about)
#
# “Try not to become a man of success. Rather become a man of value.”
# by Albert Einstein
# (about)
#
# “It is better to be hated for what you are than to be loved for what you are not.”
# by André Gide
# (about)
#
# ...

# %%
type(html)
# Out:
# http.client.HTTPResponse

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.find_all('div', {"class" : "quote"})
for i in quote:
    print(i.text)
# Out:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# by Albert Einstein
# (about)
#
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# by J.K. Rowling
# (about)
#
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# by Albert Einstein
# (about)
#
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# by Jane Austen
# (about)
#
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# by Marilyn Monroe
# (about)
#
# “Try not to become a man of success. Rather become a man of value.”
# by Albert Einstein
# (about)
#
# “It is better to be hated for what you are than to be loved for what you are not.”
# by André Gide
# (about)
#
# ...

# %% [markdown]
# #### 웹 크롤링 기본 환경 준비하기

# %%
import os, re
import urllib.request as ur
from bs4 import BeautifulSoup as bs

# %%
os.chdir('c:\doit\life')

# %%
news = 'https://news.daum.net/'

# %%
soup = bs(ur.urlopen(news).read(), 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="os_unknown none unknown version_0" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="always" name="referrer">
# <meta content="Daum 뉴스" property="og:author"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content="홈" property="og:title"/>
# <meta content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
# <meta content="다음뉴스" property="og:description"/>
# <meta content="https://news.daum.net/" property="og:url"/>
# <link href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <title>홈 | 다음뉴스</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="//t1.daumcdn.net/media/kraken/news/bc87621/style.css.merged.css" rel="stylesheet" type="text/css">
# <link href="//t1.daumcdn.net/media/kraken/news/bc87621/calendar.css.merged.css" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 8]>
# ...

# %%
soup.find_all('div', {"class" : "item_issue"})
# Out:
# [<div class="item_issue" data-tiara-layer="headline1">
#  <a class="wrap_thumb" data-tiara-custom="contentUniqueKey=hamny-20220412214553680" data-tiara-id="20220412214553680" data-tiara-layer="article_main" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://v.daum.net/v/20220412214553680">
#  <img alt="" class="thumb_g" src="https://img1.daumcdn.net/thumb/S96x60ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202204%2F12%2Fkbs%2F20220412214556808movi.jpg&amp;scode=media" 가능성="" 대러="" 동참="" 바이든="" 방일,="" 압박"="" 인도에="" 정상회담="" 제재="" 커져..미,="" 한-미=""/>
#  </a>
#  <div class="cont_thumb">
#  <span class="info_thumb">
#  <span class="logo_cp">
#  <img alt="KBS" class="thumb_g" src="https://t1.daumcdn.net/media/news/news2016/cp/cp_kbs.gif"/>
#  </span>
#  <span class="txt_category">국제</span>
#  </span>
#  <strong class="tit_g">
# ...

# %%
for i in soup.find_all('div', {"class" : "item_issue"}):
    print(i.text) #텍스트만 추출
# Out:
# 국제
#
#
#
#                                     바이든 방일, 한-미 정상회담 가능성 커져..미, 인도에 대러 제재 동참 압박
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     정읍시장 후보 여론조사 "현역 프리미엄 사라져".. 3자구도 '치열'
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     삼표산업, "양주 채석장 작업 재개 요청"..2번 반려
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     오미크론 'XL변이' 국내 첫 발생, 영향은 크지 않을 듯..인원·시간 제한 풀릴까
#
#
#
#
#
#
#
#
#
#
#
#
#
# 경제
#
#
#
#                                     동행 취재해봤더니..원산지 관리 대책 시급
#
#
#
#
#
#
#
#
#
#
#
#
#
# 정치
#
#
#
#                                     尹 취임식에 박근혜 초청.."참 면목 없다, 늘 죄송했다"
#
#
#
#
#
#
#
#
#
#
#
#
#
# IT
#
#
#
#                                     넷플릭스 부사장, 韓국회의원 만남 재추진..19일 유력
#
#
#
#
#
#
#
#
#
#
#
#
#
# 정치
#
#
#
#                                     '검수완박 당론' 민주당 의총 "경찰 비대화" "조급" 우려 나왔지만..
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     "이제 희망이 생겼어요"..심장병 아들 돌보려 간호사  도전
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
soup.find_all('a')[:5]
# Out:
# [<a href="#mainContent">본문 바로가기</a>,
#  <a href="#gnbContent">메뉴 바로가기</a>,
#  <a class="link_daum" data-tiara-layer="gnb default logo" href="https://www.daum.net/">
#  <img alt="Daum" class="logo_daum" height="18" src="//t1.daumcdn.net/media/common/newsview_2021/pc/rtn/logo_daum.png" width="44"/>
#  </a>,
#  <a data-tiara-layer="GNB service news" href="https://news.daum.net/" id="kakaoServiceLogo">
#  <span class="ir_wa">뉴스</span>
#  </a>,
#  <a class="link_services" data-tiara-layer="enter" href="https://entertain.daum.net">연예</a>]

# %%
for i in soup.find_all('a')[:5]:
    print(i.get('href')) #get은 특정 속성 값만 가져온다.
# Out:
# #mainContent
# #gnbContent
# https://www.daum.net/
# https://news.daum.net/
# https://entertain.daum.net

# %%
for i in soup.find_all('div', {"class" : "item_issue"}):
    print(i.find_all('a')[0].get('href'))
# Out:
# https://v.daum.net/v/20220412214553680
# https://v.daum.net/v/20220412214500656
# https://v.daum.net/v/20220412213947540
# https://v.daum.net/v/20220412213916531
# https://v.daum.net/v/20220412213435467
# https://v.daum.net/v/20220412212810374
# https://v.daum.net/v/20220412212750368
# https://v.daum.net/v/20220412212602322
# https://v.daum.net/v/20220412212044207
# https://v.daum.net/v/20220412211619125
# https://v.daum.net/v/20220412212001191
# https://v.daum.net/v/20220412211830163
# https://v.daum.net/v/20220412211602114
# https://v.daum.net/v/20220412211602113
# https://v.daum.net/v/20220412211038995
# https://v.daum.net/v/20220412211038996
# https://v.daum.net/v/20220412210938973
# https://v.daum.net/v/20220412210840952
# https://v.daum.net/v/20220412210304805
# https://v.daum.net/v/20220412205803683

# %%
article1 = 'https://v.daum.net/v/20220412192638799'
soup2 = bs(ur.urlopen(article1).read(), 'html.parser')
soup2
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head data-cloud-area="head">
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <style>
#             @import url('//t1.daumcdn.net/harmony_static/cloud/page/ad23f0c9e6dfe91eebd21c5a9bf5fb189c454f1c1648095650663.css');
#             @import url('//t1.daumcdn.net/harmony_static/cloud/2022/03/24/common.ad2410f730e5fb126f3d.css')
#         </style>
# <style>
#             /* 다음 카페 소셜 쉐어 임시 비활성화 */
#             .list_sns li:nth-child(6) {
#                 display: none;
#             }
#         </style>
# <meta content="E6kV2aMANx" property="mccp:docId"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content='"외국자본 50% 이하"..녹지국제병원 두번째 허가 취소될듯' property="og:title"/>
# <meta content="20220412192638" property="og:regDate"/>
# <meta content="article" property="og:type"/>
# <meta content="뉴스1" property="og:article:author"/>
# <meta content="https://news.v.daum.net/v/E6kV2aMANx" property="og:url"/>
# ...

# %%
for i in soup2.find_all('p'):
    print(i.text)
# Out:
# 국내 첫 영리병원으로 추진됐던 녹지국제병원의 개설 허가가 다시 취소될 것으로 보인다.
# 제주도보건의료정책심의위원회는 12일 오후 제주농어업인회관에서 회의를 열어 제주도가 상정한 '녹지국제병원 외국의료기관 개설 허가 취소 건'을 심사해 가결한 것으로 알려졌다.
# 녹지측은 개설 허가 취소 소송에서 최종 승소한 뒤인 지난 2월 내국인 진료 제한 조건을 풀면 영리병원을 재추진할 의사가 있다고 제주도에 전달했다.
# Translated by kakao i
# The copyright belongs to the original writer of the content, and there may be errors in machine translation results.
# 版权归内容原作者所有。机器翻译结果可能存在错误。
# 原文の著作権は原著著作者にあり、機械翻訳の結果にエラーが含まれることがあります。
# Hak cipta milik penulis asli dari konten, dan mungkin ditemukan kesalahan dalam hasil terjemahan mesin.
# Bản quyền thuộc về tác giả gốc của nội dung và có thể có lỗi trong kết quả dịch bằng máy.
#
# (제주=뉴스1) 고동명 기자 = 국내 첫 영리병원으로 추진됐던 녹지국제병원의 개설 허가가 다시 취소될 것으로 보인다.
# 제주도보건의료정책심의위원회는 12일 오후 제주농어업인회관에서 회의를 열어 제주도가 상정한 '녹지국제병원 외국의료기관 개설 허가 취소 건'을 심사해 가결한 것으로 알려졌다.
# 심의위는 이날 중국 녹지그룹 자회사이자 녹지국제병원을 허가받은 녹지제주헬스케어타운 유한회사가 제주특별법상 외국인 투자 비율을 충족하지 못했다고 판단했다.
# 영리병원 설립은 제주특별법 등에 따라 병원 지분의 50% 이상을 보유한 외국법인만 가능해 녹지가 당장 영리병원을 운영할 수는 없다.
# ...

# %%
for i in soup2.find_all('h3', {"class" : "tit_view"}):
    print(i.text)
# Out:
# "외국자본 50% 이하"..녹지국제병원 두번째 허가 취소될듯

# %%
soup = bs(ur.urlopen('https://news.daum.net').read(), 'html.parser')
headline = soup.find_all('div', {"class" : "item_issue"})
headline[0].text.replace("\n", '')[38:-32]
# Out:
# '바이든 방일, 한-미 정상회담 가능성 커져..미, 인도에 대러 제재 동참 압박'

# %%
for i in headline:
    print(i.text.replace("\n", '')[38:-32])
# Out:
# 바이든 방일, 한-미 정상회담 가능성 커져..미, 인도에 대러 제재 동참 압박
# 정읍시장 후보 여론조사 "현역 프리미엄 사라져".. 3자구도 '치열'
# 삼표산업, "양주 채석장 작업 재개 요청"..2번 반려
# 오미크론 'XL변이' 국내 첫 발생, 영향은 크지 않을 듯..인원·시간 제한 풀릴까
# 동행 취재해봤더니..원산지 관리 대책 시급
# 尹 취임식에 박근혜 초청.."참 면목 없다, 늘 죄송했다"
# 넷플릭스 부사장, 韓국회의원 만남 재추진..19일 유력
# '검수완박 당론' 민주당 의총 "경찰 비대화" "조급" 우려 나왔지만..
# "이제 희망이 생겼어요"..심장병 아들 돌보려 간호사  도전
# 청주 아파트 하락 지속..향후 전망은 엇갈려
# 코로나 엔데믹, 항공주 탑픽은 델타?..실적 발표 앞두고 급등[오미주]
# 한덕수의 주미 대사관 정부예산으로 골프장 연회비 등 지출
# 분산에너지특구..출력제어 해법 부상
# 전방위 여론전 나선 검찰..'검수완박' 민주당 당론 채택에 허탈
# 문재인·윤석열에 모두 치명타? 충격적인 특수활동비 지출 방식[영상]
# 중간고사.."확진시 시험불가" 논란 지속
# 전직 대통령 예우·건강 걱정..尹·朴 온기 돈 '50분', 보수통합 시동
# 김남국 "자신의 이해와 관련된 검찰개혁 안에 집단 항명하는 검찰, 너무 오만한 태도"[주진우 라이브]
# "의료수가로 매출 올려" 지적에..의료계 "일시적 현상"
# 지사 도전 이혜훈 컷오프..박경국, 오제세, 김영환 3파전

# %%
news = 'https://news.daum.net'
soup = bs(ur.urlopen('https://news.daum.net').read(), 'html.parser')
headline = soup.find_all('div', {"class" : "item_issue"})
for i in headline:
    #print(i.text.replace("\n", '')[38:-32], '\n')
    print(i.text.replace("\n", '').replace('  ', '')[2:], "\n")
    url = i.find_all('a')[0].get('href')
    soup3 = bs(ur.urlopen(url).read(), 'html.parser')
    for i in soup3.find_all('p'): #[10:-4]:
        if re.match('[가-힣]+', i.text):
            print(i.text)
    print()
# Out:
# 바이든 방일, 한-미 정상회담 가능성 커져..미, 인도에 대러 제재 동참 압박
#
# 조 바이든 미국 대통령이 다음 달 일본에 가겠다고 밝히면서 서울에서 한미 정상회담이 열릴 가능성도 커지고 있습니다.
# 미국과 인도의 화상 정상회담에서 나온 얘기인데, 러시아 제재와 관련해선 두 나라가 뚜렷한 결론을 내지 못한 걸로 보입니다.
# 워싱턴 김기현 특파원입니다.
# 조 바이든 미국 대통령이 나렌드라 모디 인도 총리와 화상 정상회담에서 다음 달 일본에서 만남을 기대한다고 밝혔습니다.
# 주최국 일본 정부 발표에 앞서 4개국 협력체, 쿼드 정상회담 참석을 사실상 공식화한 것입니다.
# 이에 따라 다음 달 10일 차기 정부 출범과 맞물려 바이든 대통령의 방한과 한미 정상회담 조기 개최 여부에 관심이 쏠리고 있습니다.
# 백악관은 일단, 바이든 대통령이 일본을 포함한 아시아 순방 계획이 있다면서도 시기에 관해선 말을 아꼈습니다.
# 이와 관련해 외교부는 한·미 정상회담이 조속히 개최되도록 적극적으로 노력해 나간다는 방침이라며 미국 측에서 제안해 온다면 시기와 상관없이 언제든 환영한다는 입장을 내놨습니다.
# 아시아 순방 계획은 미국 측이 인도 정상은 물론 외교와 국방부 장관들과도 만나 러시아 제재 동참을 압박하는 과정에서 표면화됐습니다.
# 인도 정부는 그러나, 유럽을 예로 들며 제재 참여 여부는 스스로 결정할 문제라고 반박했습니다.
# 인도는 우크라이나 전쟁 이후 러시아 제재에 동참하지 않고 있고, 유엔 결의안 투표도 잇따라 기권했습니다.
# 워싱턴에서 KBS 뉴스 김기현입니다.
# 촬영기자:오범석/영상편집:서삼현/그래픽:김지훈/자료조사:이세영 안소현
# 김기현 기자 (kimkh@kbs.co.kr)
# 저작권자ⓒ KBS(news.kbs.co.kr) 무단복제-재배포 금지
# 해당 언론사로 연결됩니다.
#
# 정읍시장 후보 여론조사 "현역 프리미엄 사라져".. 3자구도 '치열'
#
# ...

# %% [markdown]
# #### 프로그램 실행 파일 만들기

# %%
import os
os.chdir('C:\doit\life')

f = open('links.txt', 'w')

for i in soup.find_all('div', {"class" : "item_issue"}):
    f.write(i.find_all('a')[0].get('href') + '\n')
f.close()

# %%
url = 'https://news.daum.net/'
soup = bs(ur.urlopen(url).read(), 'html.parser')

f = open('article_total.txt', 'w', encoding = 'utf-8')

for i in soup.find_all('div', {"class" : "item_issue"}):
    try:
        f.write(i.text + '\n') #제목
        f.write(i.find_all('a')[0].get('href') + '\n')
        soup2 = bs(ur.urlopen(i.find_all('a')[0].get('href')).read(), 'html.parser')
        for j in soup2.find_all('p'):
            if re.match('[가-힣]+', j.text):
                f.write(j.text)
            
    except:
        pass
    
f.close()

# %%
import os, codecs, re, datetime, requests
import urllib.request as ur
from bs4 import BeautifulSoup as bs
os.chdir(r'c:\doit')
url = 'https://news.daum.net/'
soup = bs(ur.urlopen(url).read(), 'html.parser')
f = open(str(datetime.date.today()) + 'article_total.txt', 'w')
for i in soup.find_all('div', {'class':'item_issue'}):
    try:
        f.write(i.text+'\n') #제목
        #f.write(i.text.replace("\n",'').replace('  ','')[2:],  '\n')
        f.write(i.find_all('a')[0].get('href')+'\n') #기사URL
        soup2 = bs(ur.urlopen(i.find_all('a')[0].get('href')).read(), 'html.parser')
        for j in soup2.find_all('p'):#[10:-4]:
            if re.match('[가-힣]+',j.text):
                f.write(j.text)
    except:
        pass

f.close()

# %%
# !pip install pyinstaller

# %%
# !pyinstaller --onefile article_collector.py
# Out:
# 1863 INFO: PyInstaller: 4.10
# 1863 INFO: Python: 3.9.7 (conda)
# 1873 INFO: Platform: Windows-10-10.0.22000-SP0
# 1881 INFO: wrote c:\doit\article_collector.spec
# 1889 INFO: UPX is not available.
# 1893 INFO: Extending PYTHONPATH with paths
# ['c:\\doit']
# 2386 INFO: checking Analysis
# 2401 INFO: Building Analysis because Analysis-00.toc is non existent
# 2401 INFO: Initializing module dependency graph...
# 2410 INFO: Caching module graph hooks...
# 2417 INFO: Analyzing base_library.zip ...
# 7940 INFO: Processing pre-find module path hook distutils from 'C:\\Users\\JAKE\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path\\hook-distutils.py'.
# 7940 INFO: distutils: retargeting to non-venv dir 'C:\\Users\\JAKE\\anaconda3\\lib'
# 12112 INFO: Caching module dependency graph...
# 12289 INFO: running Analysis Analysis-00.toc
# 12322 INFO: Adding Microsoft.Windows.Common-Controls to dependent assemblies of final executable
# ...
